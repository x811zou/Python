# %%
import sys
import numpy as np
import pickle
import os
import pandas as pd
import math
import matplotlib.pyplot as plt
from pathlib import Path
root_path=Path.cwd().parent
sys.path.append(str(root_path))
from shared_code import read_data,ROC_common,ROC_noLAMBDA,power,functions
from pickle import dump, load
from math import log,log2

# %%
BEASTIE_path="/home/scarlett/github/BEASTIE"
sys.path.append(str(BEASTIE_path))
from BEASTIE import predict_lambda_GAM

# %% [markdown]
# **Power curve across different models<br>1. testing case<br>2. parametrized simulator<br>3. semi empirical simulator**

# %%
DCC_path="/data2/stan"
gam_model= load(open("/home/scarlett/github/BEASTIE/BEASTIE/iBEASTIE3_s0.7_GAM/gam4_lambdamodel.pkl", "rb"))
expected_type1error=0.05/1000
candidate_lambdas = np.linspace(1, 3, 2000)
null_cutoff=95

# %% [markdown]
# ### testing case in power analysis

# %% [markdown]
# ##### BEASTIE

# %%
predict_lambda_GAM.get_lambda_from_gam(gam_model, log(1), log(100), expected_type1error,candidate_lambdas)
# Out:
# 2.0855422711

# %%
POS="g-1000_h-10_d-20_t-0.75_s-0.7.pickle"
NEG="g-1000_h-10_d-20_t-1_s-0.7.pickle"
path="/data2/stan/BEASTIE3-pi0.05/sigma0.7/parametrized/ASE_0.05_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(10), log(100), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="iBEASTIE3",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.1865927964 for type1error 5e-05

# %%
POS="g-1000_h-1_d-50_t-0.5_s-0.7.pickle"
NEG="g-1000_h-1_d-50_t-1_s-0.7.pickle"
path="/data2/stan/iBEASTIE3/sigma0.7/parametrized/ASE_0_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(1), log(50), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="iBEASTIE3",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.4587288644 for type1error 5e-05

# %%
POS="g-1000_h-1_d-100_t-0.5_s-0.7.pickle"
NEG="g-1000_h-1_d-100_t-1_s-0.7.pickle"
path="/data2/stan/iBEASTIE3/sigma0.7/parametrized/ASE_0_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(1), log(100), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="iBEASTIE3",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.0855422711 for type1error 5e-05

# %%
POS="g-1000_h-10_d-100_t-0.25_s-0.7.pickle"
NEG="g-1000_h-10_d-100_t-1_s-0.7.pickle"
path="/data2/stan/iBEASTIE3/sigma0.7/parametrized/ASE_0_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(10), log(100), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="iBEASTIE3",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.1865927964 for type1error 5e-05

# %%
POS="g-1000_h-10_d-100_t-0.25_s-0.7.pickle"
NEG="g-1000_h-10_d-100_t-1_s-0.7.pickle"
path="/data2/stan/iBEASTIE3/sigma0.7/parametrized/ASE_0.05_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(10), log(100), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="iBEASTIE3",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.1865927964 for type1error 5e-05

# %%
POS="g-1000_h-10_d-100_t-0.25_s-0.7.pickle"
NEG="g-1000_h-10_d-100_t-1_s-0.7.pickle"
path="/data2/stan/BEASTIE3-pi0.05/sigma0.7/parametrized/ASE_0.05_error/output_pkl"
predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(10), log(100), expected_type1error,candidate_lambdas)
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="BEASTIE3-pi0.05",calculation="max_prob",lambdas=predicted_lambda)
# Out:
# predicted lambda: 2.1865927964 for type1error 5e-05

# %% [markdown]
# ##### binomial test
# ##### if we use type1error directly as cutoff, then:

# %%
POS="g-1000_h-1_d-50_t-0.75.pickle"
NEG="g-1000_h-1_d-50_t-1.pickle"
path="/data2/stan/binomial/parametrized/ASE_0_error/NS_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="NS",if_AA_baseline=True)

# %%
POS="g-1000_h-5_d-50_t-0.5.pickle"
NEG="g-1000_h-5_d-50_t-1.pickle"
path="/data2/stan/binomial/parametrized/ASE_0_error/NS_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="NS",if_AA_baseline=True)

# %%
POS="g-1000_h-1_d-100_t-0.5.pickle"
NEG="g-1000_h-1_d-100_t-1.pickle"
path="/data2/stan/binomial/parametrized/ASE_0_error/NS_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,expected_type1error=expected_type1error,title="NS",if_AA_baseline=True)

# %% [markdown]
# ##### beta-binomial test

# %%
POS="g-1000_h-1_d-50_t-0.5.pickle"
NEG="g-1000_h-1_d-50_t-1.pickle"
path="/data2/stan/betabinomial/parametrized/ASE_0_error/betabinom_100_100_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,title="beta binomial(100,100)",expected_type1error=expected_type1error,if_beta=True)

# %%
POS="g-1000_h-5_d-50_t-0.5.pickle"
NEG="g-1000_h-5_d-50_t-1.pickle"
path="/data2/stan/betabinomial/parametrized/ASE_0_error/betabinom_100_100_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,title="beta binomial(100,100)",expected_type1error=expected_type1error,if_beta=True)

# %%
POS="g-1000_h-10_d-100_t-0.5.pickle"
NEG="g-1000_h-10_d-100_t-1.pickle"
path="/data2/stan/betabinomial/parametrized/ASE_0_error/betabinom_100_100_p"
power.Plot_cutoff(POS,NEG,path,null_cutoff,title="beta binomial(100,100)",expected_type1error=expected_type1error,if_beta=True)

# %% [markdown]
# #### betabinomial 1-sided test

# %%
from scipy import stats
A=50
AR=100
1-stats.betabinom.cdf(A,AR, 1, 1)
# Out:
# 0.4950495049504947

# %%
from scipy import stats
A=33
AR=99
1-stats.betabinom.cdf(A,AR, 1, 1)
# Out:
# 0.6600000000000007

# %% [markdown]
# #### betabinomial 2-sided test1

# %%
from scipy import stats
A=50
AR=100
p_lower=stats.betabinom.cdf(A,AR, 1, 1)
p_upper=1-stats.betabinom.cdf(A+1,AR, 1, 1)
p_lower+p_upper
# Out:
# 0.9900990099009901

# %%
from scipy import stats
A=33
AR=100
p_lower=stats.betabinom.cdf(A,AR, 1, 1)
p_upper=1-stats.betabinom.cdf(A+1,AR, 1, 1)
p_lower+p_upper
# Out:
# 0.9900990099009901

# %% [markdown]
# #### betabinomial 2-sided test2

# %%
from scipy import stats
A=50
AR=100
2*min(stats.betabinom.cdf(A,AR, 1, 1),1-stats.betabinom.cdf(A,AR, 1, 1))
# Out:
# 0.9900990099009894

# %%
from scipy import stats
A=33
AR=100
2*min(stats.betabinom.cdf(A,AR, 1, 1),1-stats.betabinom.cdf(A,AR, 1, 1))
# Out:
# 0.6732673267326736

# %%
def Find_cutoff_from_Null_allmodels(model, percentError,theta_alt,cutoff,expected_type1error,model2=None,gene=None,hets=None,depth=None,sigma=None,num=3,if_AA=False,calculation="max_prob"):
    source="/data2/stan/"
    gam_model= load(open("/home/scarlett/github/BEASTIE/BEASTIE/iBEASTIE3_s0.7_GAM/gam4_lambdamodel.pkl", "rb"))
    candidate_lambdas = np.linspace(1, 3, 2000)
    # judge whether  2 of the 4 are None, and 2 of the 4 are not None
    theta_pos=theta_alt
    theta_neg=1

    var=[gene,hets,depth,sigma]        
    if var.count(None)!=2:
        raise Exception('Two variables have to be set to None. The number of None from input was {}'.format(var.count(None)))
    # data directory is known 
    if if_AA:
        path_AA=f"{source}/ADM/{percentError}/AA_pval"
    else:   
        path_AA=None

    path_model,path_NS,path_MS,path_model2,path_beta1,path_beta2,path_beta3 = power.Generate_path_power(source=source,model=model,sigma=sigma,workdir=percentError,model2=model2,calculation=calculation)
    d_group,var,var_map_np,fixed_var_np,var_fullname_map_np,variable_var_np,pos_pd,neg_pd = power.Prepare_data_fix(gene, hets, depth, sigma,source,model,percentError,theta_pos,theta_neg=1,Num_para=2)

    ############################################################
    read_depth = pos_pd[var_map_np[np.array(var) == None][1]].unique()

    if num == None:
        num = 3
    else:
        num = int(num)
    row = math.ceil(float(len(d_group))/num)
    fig, axs = plt.subplots(row, num, figsize = (25,8*row))
    if (row * num > len(d_group)):
        for i in range(row * num - len(d_group)):
            axs.flat[-1-i].set_axis_off()

    xlabels = "Data with %s percent error, gene: %s , sigma: %s, expected type1 at %s"%(str(percentError),gene,sigma,expected_type1error)

    labels = ""

    for i, each in enumerate(d_group):
        current_group_pos_list = pos_pd[pos_pd[var_map_np[np.array(var) == None][0]] == each].index
        current_group_neg_list = neg_pd[neg_pd[var_map_np[np.array(var) == None][0]] == each].index
        power_model_list=[]
        power_model2_list=[]
        power_NS_list=[]
        power_MS_list=[]
        power_adam_list=[]
        power_beta11_list=[]
        power_beta1010_list=[]
        power_beta2020_list=[]

        for idx in range(len(current_group_pos_list)):
            #print(current_group_pos_list[idx])

            reduced_file_pos = current_group_pos_list[idx].rsplit("_",1)[0]+".pickle"
            reduced_file_neg = current_group_neg_list[idx].rsplit("_",1)[0]+".pickle"
            h=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
            d=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
            hets=int(h)
            totalcount=int(h)*int(d)
            predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(hets), log(totalcount), expected_type1error=expected_type1error,candidate_lambdas = np.linspace(1, 3, 2000))
            #print(predicted_lambda)
            # model
            power1,_,_,_=power.Calculate_cutoff(current_group_pos_list[idx],current_group_neg_list[idx],path_model,cutoff,expected_type1error=expected_type1error,calculation=calculation,lambdas=predicted_lambda)
            # NS
            power2,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_NS,cutoff,expected_type1error=expected_type1error,if_AA_baseline=True,calculation=calculation)
            # MS
            power3,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_MS,cutoff,expected_type1error=expected_type1error,if_AA_baseline=True,calculation=calculation)
            if if_AA:
                power4,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_AA,cutoff,if_AA_baseline=True,calculation=calculation)
                power_adam_list.append(power4)
            # second model
            #power5,_,_=power.Calculate_cutoff(current_group_pos_list[idx],current_group_neg_list[idx],path_model2,cutoff,expected_type1error=expected_type1error,calculation=calculation)
            #print(">> beta(1,1)")
            if path_beta1 is not None:
                power6,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_beta1,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                #print(">> beta(10,10)")
                power7,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_beta2,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                #print(">> beta(20,20)")
                power8,_,_,_=power.Calculate_cutoff(reduced_file_pos,reduced_file_neg,path_beta3,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                power_beta11_list.append(power6)
                power_beta1010_list.append(power7)
                power_beta2020_list.append(power8)
            # 
            power_model_list.append(power1) 
            power_NS_list.append(power2)
            power_MS_list.append(power3)

        # for each read depth, we plot    
        g=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[0].rsplit("-")[1]
        h=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
        d=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
        s=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[4].rsplit("-")[1]
        var_dict = {"gene":g, "hets": h, "depth": d, "sigma": s}
        for each in variable_var_np:
            if each != var_fullname_map_np[np.array(var) == None][0]:
                labels += each+":"+var_dict[each]+' '
        axs.flat[i].set_ylabel("Power",fontsize=20)
        axs.flat[i].set_xlabel("Read Depth per het site",fontsize=15)
        #axs.flat[i].set_ylim(0,1.1)
        #axs.flat[i].set_xlim(0,100)
        #print(power_model_list)
        axs.flat[i].plot(read_depth, power_model_list,'--o',label=str(model))
        axs.flat[i].plot(read_depth, power_model2_list,'--o',label=str(model2))
        axs.flat[i].plot(read_depth, power_NS_list,'--o',label="Naive Sum")
        axs.flat[i].plot(read_depth, power_MS_list,'--o',label="Major Site")
        #axs.flat[i].axhline(y=0.9,color='darkred',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.8,color='red',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.7,color='orangered',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.6,color='lightsalmon',alpha=0.80,linestyle='--') 
        axs.flat[i].legend(loc='best',fontsize=15)
        axs.flat[i].set_title(var_fullname_map_np[np.array(var) == None][0]+":" + var_dict[var_fullname_map_np[np.array(var) == None][0]],fontsize=20)

    plt.suptitle(xlabels,fontsize=25)
    plt.show()


def Plot_type1error(model, percentError,theta_alt,model2=None,gene=None,hets=None,depth=None,sigma=None,num=3,if_AA=False):
    source="/data2/stan/"
    gam_model= load(open("/home/scarlett/github/BEASTIE/BEASTIE/iBEASTIE3_s0.7_GAM/gam4_lambdamodel.pkl", "rb"))
    # judge whether  2 of the 4 are None, and 2 of the 4 are not Non
    theta_pos=theta_alt
    theta_neg=1

    var=[gene,hets,depth,sigma]        
    if var.count(None)!=2:
        raise Exception('Two variables have to be set to None. The number of None from input was {}'.format(var.count(None)))
    # data directory is known 
    if if_AA:
        path_AA=f"{source}/ADM/{percentError}/AA_pval"
    else:   
        path_AA=None

    path_model,path_NS,path_MS,path_model2,path_beta1,path_beta2,path_beta3 = power.Generate_path_power(source=source,model=model,sigma=sigma,workdir=percentError,model2=model2,calculation="max_prob")
    d_group,var,var_map_np,fixed_var_np,var_fullname_map_np,variable_var_np,pos_pd,neg_pd = power.Prepare_data_fix(gene, hets, depth, sigma,source,model,percentError,theta_pos,theta_neg=1,Num_para=2)

    ############################################################
    read_depth = pos_pd[var_map_np[np.array(var) == None][1]].unique()

    if num == None:
        num = 3
    else:
        num = int(num)
    row = math.ceil(float(len(d_group))/num)
    fig, axs = plt.subplots(row, num, figsize = (25,8*row))
    if (row * num > len(d_group)):
        for i in range(row * num - len(d_group)):
            axs.flat[-1-i].set_axis_off()

    xlabels = "Data with %s percent error, gene: %s , sigma: %s, ASE-cutoff for (beta)binomial set at %s"%(str(percentError),gene,sigma,expected_type1error)

    labels = ""
    #df1 = pd.DataFrame({'Model':[],'Het':[],'d5':[], 'd10':[], 'd20':[], 'd30':[], 'd40':[], 'd50':[], 'd60':[], 'd70':[], 'd80':[], 'd90':[], 'd100':[]})
    #df2=df1
    #df3=df1
    #df4=df1
    #df5=df1
    #df6=df1
    #df7=df1
    #df8=df1
    for i, each in enumerate(d_group):
        current_group_pos_list = pos_pd[pos_pd[var_map_np[np.array(var) == None][0]] == each].index
        current_group_neg_list = neg_pd[neg_pd[var_map_np[np.array(var) == None][0]] == each].index
        error_model_list=[]
        error_NS_list=[]
        error_MS_list=[]
        error_adam_list=[]
        error_beta11_list=[]
        error_beta1010_list=[]
        error_beta2020_list=[]
        #

        for idx in range(len(current_group_pos_list)):
            #print(current_group_pos_list[idx])

            reduced_file_pos = current_group_pos_list[idx].rsplit("_",1)[0]+".pickle"
            reduced_file_neg = current_group_neg_list[idx].rsplit("_",1)[0]+".pickle"
            h=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
            d=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
            hets=int(h)
            totalcount=int(h)*int(d)
            predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(hets), log(totalcount), expected_type1error=expected_type1error,candidate_lambdas = np.linspace(1, 3, 2000))
            #print(predicted_lambda)
            # model
            cutoff1=power.Calculate_type1error(current_group_neg_list[idx],path_model,expected_type1error=expected_type1error,lambdas=predicted_lambda)
            # NS
            cutoff2=power.Calculate_type1error(reduced_file_neg,path_NS,expected_type1error=expected_type1error,if_AA_baseline=True)
            # MS
            cutoff3=power.Calculate_type1error(reduced_file_neg,path_MS,expected_type1error=expected_type1error,if_AA_baseline=True)
            # if if_AA:
            #     cutoff4=power.Calculate_type1error(reduced_file_neg,path_AA,if_AA_baseline=True)
            #     error_adam_list.append(cutoff4)
            # # second model
            # #cutoff5=power.Calculate_type1error(current_group_neg_list[idx],path_model2,expected_type1error=expected_type1error,lambdas=predicted_lambda)
            # #print(">> beta(1,1)")
            # if path_beta1 is not None:
            #     cutoff6=power.Calculate_type1error(reduced_file_neg,path_beta1,expected_type1error=expected_type1error,if_beta=True)
            #     #print(">> beta(10,10)")
            #     cutoff7=power.Calculate_type1error(reduced_file_neg,path_beta2,expected_type1error=expected_type1error,if_beta=True)
            #     #print(">> beta(20,20)")
            #     cutoff8=power.Calculate_type1error(reduced_file_neg,path_beta3,expected_type1error=expected_type1error,if_beta=True)
            #     error_beta11_list.append(cutoff6)
            #     error_beta1010_list.append(cutoff7)
            #     error_beta2020_list.append(cutoff8)

            # 
            error_model_list.append(cutoff1)
            error_NS_list.append(cutoff2)
            error_MS_list.append(cutoff3)
            #error_model2_list.append(cutoff5)



        # for each read depth, we plot    
        g=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[0].rsplit("-")[1]
        h=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
        d=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
        s=current_group_pos_list[idx].rsplit(".pickle")[0].rsplit("_")[4].rsplit("-")[1]
        var_dict = {"gene":g, "hets": h, "depth": d, "sigma": s}
        for each in variable_var_np:
            if each != var_fullname_map_np[np.array(var) == None][0]:
                labels += each+":"+var_dict[each]+' '
        axs.flat[i].set_ylabel("Type 1 error",fontsize=20)
        axs.flat[i].set_xlabel("Read Depth per het site",fontsize=15)
        #axs.flat[i].set_ylim(0,0.5)
        axs.flat[i].set_xlim(0,100)
        axs.flat[i].plot(read_depth, error_model_list,'--o',label=str(model))
        #axs.flat[i].plot(read_depth, error_model2_list,'--o',label=str(model2))
        axs.flat[i].plot(read_depth, error_NS_list,'--o',label="Naive Sum")
        axs.flat[i].plot(read_depth, error_MS_list,'--o',label="Major Site")
        axs.flat[i].axhline(y=0.05,color='darkred',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.2,color='red',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.3,color='orangered',alpha=0.80,linestyle='--')
        #axs.flat[i].axhline(y=0.4,color='lightsalmon',alpha=0.80,linestyle='--') 
        axs.flat[i].legend(loc='best',fontsize=15)
        axs.flat[i].set_title(var_fullname_map_np[np.array(var) == None][0]+":" + var_dict[var_fullname_map_np[np.array(var) == None][0]],fontsize=20)
    #
    #df1 = pd.concat([df1,pd.DataFrame([{'Model':str(model)+" "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_model_list[0],4), 'd10':round(power_model_list[1],4), 'd20':round(power_model_list[2],4), 'd30':round(power_model_list[3],4), 'd40':round(power_model_list[4],4), 'd50':round(power_model_list[5],4), 'd60':round(power_model_list[6],4), 'd70':round(power_model_list[7],4), 'd80':round(power_model_list[8],4), 'd90':round(power_model_list[9],4), 'd100':round(power_model_list[10],4)}])],ignore_index=True)
    #df3 = pd.concat([df3,pd.DataFrame([{'Model':"NS "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_NS_list[0],4), 'd10':round(power_NS_list[1],4), 'd20':round(power_NS_list[2],4), 'd30':round(power_NS_list[3],4), 'd40':round(power_NS_list[4],4), 'd50':round(power_NS_list[5],4), 'd60':round(power_NS_list[6],4), 'd70':round(power_NS_list[7],4), 'd80':round(power_NS_list[8],4), 'd90':round(power_NS_list[9],4), 'd100':round(power_NS_list[10],4)}])],ignore_index=True)
    #df4 = pd.concat([df4,pd.DataFrame([{'Model':"MS "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_MS_list[0],4), 'd10':round(power_MS_list[1],4), 'd20':round(power_MS_list[2],4), 'd30':round(power_MS_list[3],4), 'd40':round(power_MS_list[4],4), 'd50':round(power_MS_list[5],4), 'd60':round(power_MS_list[6],4), 'd70':round(power_MS_list[7],4), 'd80':round(power_MS_list[8],4), 'd90':round(power_MS_list[9],4), 'd100':round(power_MS_list[10],4)}])],ignore_index=True)
    #if if_AA:
    #    df2 = pd.concat([df2,pd.DataFrame([{'Model':"ADAM "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_adam_list[0],4), 'd10':round(power_adam_list[1],4), 'd20':round(power_adam_list[2],4), 'd30':round(power_adam_list[3],4), 'd40':round(power_adam_list[4],4), 'd50':round(power_adam_list[5],4), 'd60':round(power_adam_list[6],4), 'd70':round(power_adam_list[7],4), 'd80':round(power_adam_list[8],4), 'd90':round(power_adam_list[9],4), 'd100':round(power_adam_list[10],4)}])],ignore_index=True)
    #df5 = pd.concat([df5,pd.DataFrame([{'Model':str(model2)+" "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_model2_list[0],4), 'd10':round(power_model2_list[1],4), 'd20':round(power_model2_list[2],4), 'd30':round(power_model2_list[3],4), 'd40':round(power_model2_list[4],4), 'd50':round(power_model2_list[5],4), 'd60':round(power_model2_list[6],4), 'd70':round(power_model2_list[7],4), 'd80':round(power_model2_list[8],4), 'd90':round(power_model2_list[9],4), 'd100':round(power_model2_list[10],4)}])],ignore_index=True)
    #if path_beta1 is not None:
    #    df6 = pd.concat([df6,pd.DataFrame([{'Model':"beta(1,1) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta11_list[0],4), 'd10':round(power_beta11_list[1],4), 'd20':round(power_beta11_list[2],4), 'd30':round(power_beta11_list[3],4), 'd40':round(power_beta11_list[4],4), 'd50':round(power_NS_list[5],4), 'd60':round(power_beta11_list[6],4), 'd70':round(power_beta11_list[7],4), 'd80':round(power_beta11_list[8],4), 'd90':round(power_beta11_list[9],4), 'd100':round(power_beta11_list[10],4)}])],ignore_index=True)
    #    df7 = pd.concat([df7,pd.DataFrame([{'Model':"beta(10,10) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta1010_list[0],4), 'd10':round(power_beta1010_list[1],4), 'd20':round(power_beta1010_list[2],4), 'd30':round(power_beta1010_list[3],4), 'd40':round(power_beta1010_list[4],4), 'd50':round(power_beta1010_list[5],4), 'd60':round(power_beta1010_list[6],4), 'd70':round(power_beta1010_list[7],4), 'd80':round(power_beta1010_list[8],4), 'd90':round(power_beta1010_list[9],4), 'd100':round(power_beta1010_list[10],4)}])],ignore_index=True)
    #    df8 = pd.concat([df8,pd.DataFrame([{'Model':"beta(20,20) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta2020_list[0],4), 'd10':round(power_beta2020_list[1],4), 'd20':round(power_beta2020_list[2],4), 'd30':round(power_beta2020_list[3],4), 'd40':round(power_beta2020_list[4],4), 'd50':round(power_beta2020_list[5],4), 'd60':round(power_beta2020_list[6],4), 'd70':round(power_beta2020_list[7],4), 'd80':round(power_beta2020_list[8],4), 'd90':round(power_beta2020_list[9],4), 'd100':round(power_beta2020_list[10],4)}])],ignore_index=True)

    plt.suptitle(xlabels,fontsize=25)
    plt.show()

    #df1.set_index(['Model', 'Het'])
    #df2.set_index(['Model', 'Het'])
    #df3.set_index(['Model', 'Het'])
    #df4.set_index(['Model', 'Het'])
    #df5.set_index(['Model', 'Het'])
    #df6.set_index(['Model', 'Het'])
    #df7.set_index(['Model', 'Het'])
    #df8.set_index(['Model', 'Het'])

    #final_df=pd.concat([df1,df5],axis=0,ignore_index=True)
    #final_df=pd.concat([final_df,df3],axis=0,ignore_index=True)
    #final_df=pd.concat([final_df,df4],axis=0,ignore_index=True)

    #return final_df,df1,df5,df3,df4

# %% [markdown]
# ## parametrized simulator
# ### 0% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 8
#       6 gene=1000
#       7 calculation="max_prob"
# ----> 8 Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)
#
# Cell In[45], line 102, in Find_cutoff_from_Null_allmodels(model, percentError, theta_alt, cutoff, expected_type1error, model2, gene, hets, depth, sigma, num, if_AA, calculation)
#      98 #axs.flat[i].set_ylim(0,1.1)
#      99 #axs.flat[i].set_xlim(0,100)
#     100 #print(power_model_list)
#     101 axs.flat[i].plot(read_depth, power_model_list,'--o',label=str(model))
# --> 102 axs.flat[i].plot(read_depth, power_model2_list,'--o',label=str(model2))
# ...

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.5
gene=1000
Plot_type1error(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.75
gene=1000
Plot_type1error(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0_error"
theta_alt=0.25
gene=1000
Plot_type1error(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False)

# %% [markdown]
# ### 3% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.03_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.03_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.03_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 5% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.05_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.05_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.05_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 10% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.1_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.1_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.1_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 20% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.2_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.2_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.2_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 30% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.3_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.3_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.3_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 40% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.4_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.4_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.4_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %% [markdown]
# ### 50% phasing error rate, with 1,000 genes under the null

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.5_error"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.5_error"
theta_alt=0.25
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="parametrized/ASE_0.5_error"
theta_alt=0.75
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
def Find_cutoff_from_Null_allmodels_GIAB(model, percentError,theta_alt,cutoff,expected_type1error,model2=None,gene=None,hets=None,depth=None,sigma=None,num=3,if_AA=False,calculation="max_prob"):
    source="/data2/stan/"
    gam_model= load(open("/home/scarlett/github/BEASTIE/BEASTIE/iBEASTIE3_s0.7_GAM/gam4_lambdamodel.pkl", "rb"))
    candidate_lambdas = np.linspace(1, 3, 2000)
    # judge whether  2 of the 4 are None, and 2 of the 4 are not None
    theta_pos=theta_alt
    theta_neg=1

    var=[gene,hets,depth,sigma]        
    if var.count(None)!=2:
        raise Exception('Two variables have to be set to None. The number of None from input was {}'.format(var.count(None)))
    # data directory is known 
    if if_AA:
        path_AA=f"{source}/ADM/{percentError}/AA_pval"
    else:   
        path_AA=None

    path_model,path_NS,path_MS,path_model2,path_beta1,path_beta2,path_beta3 = power.Generate_path_power(source=source,model=model,sigma=sigma,workdir=percentError,model2=model2,calculation=calculation)
    d_group,var,var_map_np,fixed_var_np,var_fullname_map_np,variable_var_np,pos_pd,neg_pd = Prepare_data_fix_GIAB(gene, hets, depth, sigma,source,model,percentError,theta_pos=theta_pos,theta_neg=theta_neg,Num_para=2)
    sys.exit()
    ############################################################
    read_depth = pos_pd[var_map_np[np.array(var) == None][1]].unique()

    if num == None:
        num = 3
    else:
        num = int(num)
    row = math.ceil(float(len(d_group))/num)
    fig, axs = plt.subplots(row, num, figsize = (25,8*row))
    if (row * num > len(d_group)):
        for i in range(row * num - len(d_group)):
            axs.flat[-1-i].set_axis_off()

    xlabels = "Data with %s percent error, gene: %s , sigma: %s, expected type1 at %s"%(str(percentError),gene,sigma,expected_type1error)

    labels = ""
    #df1 = pd.DataFrame({'Model':[],'Het':[],'d5':[], 'd10':[], 'd20':[], 'd30':[], 'd40':[], 'd50':[], 'd60':[], 'd70':[], 'd80':[], 'd90':[], 'd100':[]})
    #df2=df1
    #df3=df1
    #df4=df1
    #df5=df1
    #df6=df1
    #df7=df1
    #df8=df1
    for i, each in enumerate(d_group):
        current_group_pos_list = pos_pd[pos_pd[var_map_np[np.array(var) == None][0]] == each].index
        current_group_neg_list = neg_pd[neg_pd[var_map_np[np.array(var) == None][0]] == each].index
        power_model_list=[]
        power_NS_list=[]
        power_MS_list=[]
        power_adam_list=[]
        power_beta11_list=[]
        power_beta1010_list=[]
        power_beta2020_list=[]

        for idx in range(len(current_group_pos_list)):
            if "CEU_" in percentError:
                name = current_group_pos_list[idx].replace("_CEU", "")
            if "CEU_enrichedEr" in percentError:
                name = current_group_pos_list[idx].replace("_CEU_enrichedEr", "")
            g=name.rsplit(".pickle")[0].rsplit("_")[0].rsplit("-")[1]
            h=name.rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
            d=name.rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
            t=name.rsplit(".pickle")[0].rsplit("_")[3].rsplit("-")[1]
            s=name.rsplit(".pickle")[0].rsplit("_")[4].rsplit("-")[1] 
            hets=int(h)
            totalcount=int(h)*int(d)
            if "CEU/g-1000" in percentError:
                new_POS = f"g-{g}_h-{h}_d-{d}_t-{theta_alt}_CEU_s-{s}.pickle"
                new_NEG = f"g-{g}_h-{h}_d-{d}_t-{theta_neg}_CEU_s-{s}.pickle"
                reduced_POS=f"g-{g}_h-{h}_d-{d}_t-{theta_alt}_CEU.pickle"
                reduced_NEG=f"g-{g}_h-{h}_d-{d}_t-{theta_neg}_CEU.pickle"
            elif "CEU_enrichedEr" in percentError:
                new_POS = f"g-{g}_h-{h}_d-{d}_t-{theta_alt}_CEU_enrichedEr_s-{s}.pickle"
                new_NEG = f"g-{g}_h-{h}_d-{d}_t-{theta_neg}_CEU_enrichedEr_s-{s}.pickle"
                reduced_POS=f"g-{g}_h-{h}_d-{d}_t-{theta_alt}_CEU_enrichedEr.pickle"
                reduced_NEG=f"g-{g}_h-{h}_d-{d}_t-{theta_neg}_CEU_enrichedEr.pickle"
            else:
                new_POS = f"g-{g}_h-{h}_d-{d}_t-{theta_alt}_s-{s}.pickle"
                new_NEG = f"g-{g}_h-{h}_d-{d}_t-{theta_neg}_s-{s}.pickle" 
                reduced_POS=f"g-{g}_h-{h}_d-{d}_t-{theta_alt}.pickle"
                reduced_NEG=f"g-{g}_h-{h}_d-{d}_t-{theta_neg}.pickle"
            predicted_lambda=predict_lambda_GAM.get_lambda_from_gam(gam_model, log(hets), log(totalcount), expected_type1error=expected_type1error,candidate_lambdas = np.linspace(1, 3, 2000))
            #print(predicted_lambda)
            # model
            power1,_,_=power.Calculate_cutoff(new_POS,new_NEG,path_model,cutoff,expected_type1error=expected_type1error,calculation=calculation,lambdas=predicted_lambda)
            # NS
            power2,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_NS,cutoff,expected_type1error=expected_type1error,if_AA_baseline=True,calculation=calculation)
            # MS
            power3,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_MS,cutoff,expected_type1error=expected_type1error,if_AA_baseline=True,calculation=calculation)
            if if_AA:
                power4,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_AA,cutoff,if_AA_baseline=True,calculation=calculation)
                power_adam_list.append(power4)
            # second model
            #power5,_,_=power.Calculate_cutoff(current_group_pos_list[idx],current_group_neg_list[idx],path_model2,cutoff,expected_type1error=expected_type1error,calculation=calculation)
            #print(">> beta(1,1)")
            if path_beta1 is not None:
                power6,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_beta1,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                #print(">> beta(10,10)")
                power7,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_beta2,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                #print(">> beta(20,20)")
                power8,_,_=power.Calculate_cutoff(reduced_POS,reduced_NEG,path_beta3,cutoff,expected_type1error=expected_type1error,if_beta=True,calculation=calculation)
                power_beta11_list.append(power6)
                power_beta1010_list.append(power7)
                power_beta2020_list.append(power8)
            # 
            power_model_list.append(power1) 
            power_NS_list.append(power2)
            power_MS_list.append(power3)
            #power_model2_list.append(power5) 

        # for each read depth, we plot    
        g=name.rsplit(".pickle")[0].rsplit("_")[0].rsplit("-")[1]
        h=name.rsplit(".pickle")[0].rsplit("_")[1].rsplit("-")[1]
        d=name.rsplit(".pickle")[0].rsplit("_")[2].rsplit("-")[1]
        s=name.rsplit(".pickle")[0].rsplit("_")[4].rsplit("-")[1]
        var_dict = {"gene":g, "hets": h, "depth": d, "sigma": s}
        for each in variable_var_np:
            if each != var_fullname_map_np[np.array(var) == None][0]:
                labels += each+":"+var_dict[each]+' '
        axs.flat[i].set_ylabel("Power",fontsize=20)
        axs.flat[i].set_xlabel("Read Depth per het site",fontsize=15)
        axs.flat[i].set_ylim(0,1.1)
        axs.flat[i].set_xlim(0,100)
        axs.flat[i].plot(read_depth, power_model_list,'--o',label=str(model))
        #axs.flat[i].plot(read_depth, power_model2_list,'--o',label=str(model2))
        axs.flat[i].plot(read_depth, power_NS_list,'--o',label="Naive Sum")
        axs.flat[i].plot(read_depth, power_MS_list,'--o',label="Major Site")
        if path_beta1 is not None:
            axs.flat[i].plot(read_depth, power_beta11_list,'--o',label="betabinom (1,1)")
            axs.flat[i].plot(read_depth, power_beta1010_list,'--o',label="betabinom (50,50)")
            axs.flat[i].plot(read_depth, power_beta2020_list,'--o',label="betabinom (100,100)")
        if if_AA:
            axs.flat[i].plot(read_depth, power_adam_list,'--bo',label="ADAM")
        axs.flat[i].axhline(y=0.9,color='darkred',alpha=0.80,linestyle='--')
        axs.flat[i].axhline(y=0.8,color='red',alpha=0.80,linestyle='--')
        axs.flat[i].axhline(y=0.7,color='orangered',alpha=0.80,linestyle='--')
        axs.flat[i].axhline(y=0.6,color='lightsalmon',alpha=0.80,linestyle='--') 
        axs.flat[i].legend(loc='best',fontsize=15)
        axs.flat[i].set_title(var_fullname_map_np[np.array(var) == None][0]+":" + var_dict[var_fullname_map_np[np.array(var) == None][0]],fontsize=20)
    #
    #df1 = pd.concat([df1,pd.DataFrame([{'Model':str(model)+" "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_model_list[0],4), 'd10':round(power_model_list[1],4), 'd20':round(power_model_list[2],4), 'd30':round(power_model_list[3],4), 'd40':round(power_model_list[4],4), 'd50':round(power_model_list[5],4), 'd60':round(power_model_list[6],4), 'd70':round(power_model_list[7],4), 'd80':round(power_model_list[8],4), 'd90':round(power_model_list[9],4), 'd100':round(power_model_list[10],4)}])],ignore_index=True)
    #df3 = pd.concat([df3,pd.DataFrame([{'Model':"NS "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_NS_list[0],4), 'd10':round(power_NS_list[1],4), 'd20':round(power_NS_list[2],4), 'd30':round(power_NS_list[3],4), 'd40':round(power_NS_list[4],4), 'd50':round(power_NS_list[5],4), 'd60':round(power_NS_list[6],4), 'd70':round(power_NS_list[7],4), 'd80':round(power_NS_list[8],4), 'd90':round(power_NS_list[9],4), 'd100':round(power_NS_list[10],4)}])],ignore_index=True)
    #df4 = pd.concat([df4,pd.DataFrame([{'Model':"MS "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_MS_list[0],4), 'd10':round(power_MS_list[1],4), 'd20':round(power_MS_list[2],4), 'd30':round(power_MS_list[3],4), 'd40':round(power_MS_list[4],4), 'd50':round(power_MS_list[5],4), 'd60':round(power_MS_list[6],4), 'd70':round(power_MS_list[7],4), 'd80':round(power_MS_list[8],4), 'd90':round(power_MS_list[9],4), 'd100':round(power_MS_list[10],4)}])],ignore_index=True)
    #if if_AA:
    #    df2 = pd.concat([df2,pd.DataFrame([{'Model':"ADAM "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_adam_list[0],4), 'd10':round(power_adam_list[1],4), 'd20':round(power_adam_list[2],4), 'd30':round(power_adam_list[3],4), 'd40':round(power_adam_list[4],4), 'd50':round(power_adam_list[5],4), 'd60':round(power_adam_list[6],4), 'd70':round(power_adam_list[7],4), 'd80':round(power_adam_list[8],4), 'd90':round(power_adam_list[9],4), 'd100':round(power_adam_list[10],4)}])],ignore_index=True)
    #df5 = pd.concat([df5,pd.DataFrame([{'Model':str(model2)+" "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_model2_list[0],4), 'd10':round(power_model2_list[1],4), 'd20':round(power_model2_list[2],4), 'd30':round(power_model2_list[3],4), 'd40':round(power_model2_list[4],4), 'd50':round(power_model2_list[5],4), 'd60':round(power_model2_list[6],4), 'd70':round(power_model2_list[7],4), 'd80':round(power_model2_list[8],4), 'd90':round(power_model2_list[9],4), 'd100':round(power_model2_list[10],4)}])],ignore_index=True)
    #if path_beta1 is not None:
    #    df6 = pd.concat([df6,pd.DataFrame([{'Model':"beta(1,1) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta11_list[0],4), 'd10':round(power_beta11_list[1],4), 'd20':round(power_beta11_list[2],4), 'd30':round(power_beta11_list[3],4), 'd40':round(power_beta11_list[4],4), 'd50':round(power_NS_list[5],4), 'd60':round(power_beta11_list[6],4), 'd70':round(power_beta11_list[7],4), 'd80':round(power_beta11_list[8],4), 'd90':round(power_beta11_list[9],4), 'd100':round(power_beta11_list[10],4)}])],ignore_index=True)
    #    df7 = pd.concat([df7,pd.DataFrame([{'Model':"beta(10,10) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta1010_list[0],4), 'd10':round(power_beta1010_list[1],4), 'd20':round(power_beta1010_list[2],4), 'd30':round(power_beta1010_list[3],4), 'd40':round(power_beta1010_list[4],4), 'd50':round(power_beta1010_list[5],4), 'd60':round(power_beta1010_list[6],4), 'd70':round(power_beta1010_list[7],4), 'd80':round(power_beta1010_list[8],4), 'd90':round(power_beta1010_list[9],4), 'd100':round(power_beta1010_list[10],4)}])],ignore_index=True)
    #    df8 = pd.concat([df8,pd.DataFrame([{'Model':"beta(20,20) "+str(percentError),'Het':var_dict[var_fullname_map_np[np.array(var) == None][0]],'d5':round(power_beta2020_list[0],4), 'd10':round(power_beta2020_list[1],4), 'd20':round(power_beta2020_list[2],4), 'd30':round(power_beta2020_list[3],4), 'd40':round(power_beta2020_list[4],4), 'd50':round(power_beta2020_list[5],4), 'd60':round(power_beta2020_list[6],4), 'd70':round(power_beta2020_list[7],4), 'd80':round(power_beta2020_list[8],4), 'd90':round(power_beta2020_list[9],4), 'd100':round(power_beta2020_list[10],4)}])],ignore_index=True)

    plt.suptitle(xlabels,fontsize=25)
    plt.show()

    #df1.set_index(['Model', 'Het'])
    #df2.set_index(['Model', 'Het'])
    #df3.set_index(['Model', 'Het'])
    #df4.set_index(['Model', 'Het'])
    #df5.set_index(['Model', 'Het'])
    #df6.set_index(['Model', 'Het'])
    #df7.set_index(['Model', 'Het'])
    #df8.set_index(['Model', 'Het'])

    #final_df=pd.concat([df1,df5],axis=0,ignore_index=True)
    #final_df=pd.concat([final_df,df3],axis=0,ignore_index=True)
    #final_df=pd.concat([final_df,df4],axis=0,ignore_index=True)

    #return final_df,df1,df5,df3,df4



import re


def Prepare_data_fix_GIAB(gene, hets, depth, sigma, source,model,workdir,theta_pos,theta_neg,Num_para,model2=None):
    var=[gene,hets,depth,sigma]
    var_map_np = np.array(['g','h','d','s'])
    var_fullname_map_np = np.array(['gene','hets','depth','sigma'])
    full_var_map_np = np.array([gene, hets, depth, sigma])
    valid_var_np = var_map_np[np.array(var) != None]
    variable_var_np = var_fullname_map_np[np.array(var) == None]
    fixed_var_np = var_fullname_map_np[np.array(var) != None]
    valid_full_var_np = full_var_map_np[np.array(var) != None]

        
    path_model,_,_,_,_,_,_= power.Generate_path_power(source,model,sigma,workdir,model2)
    all_file = sorted(os.listdir(path_model))

    postfix=".pickle"

    all_file = [x for x in all_file if ("CEU_giab" not in x) and ("CEU_tpi" not in x) and postfix in x]

    if sigma is not None:
        all_file = [x for x in all_file if f"s-{sigma}" in x]

    regex = re.compile(r"g-(\d+)_h-(\d+)_d-(\d+)_t-(\d+)_CEU_s-(\b\d+\.\d+\b)")
    files_with_info = []
    for file in all_file:
        match = regex.match(file)
        if not match:
            continue

        file_gene = int(match.group(1))
        file_hets = int(match.group(2))
        file_depth = int(match.group(3))
        file_theta = int(match.group(4))
        file_sigma = float(match.group(5))

        if gene is not None and gene != file_gene:
           continue
        if hets is not None and hets != file_hets:
           continue
        if depth is not None and depth != file_depth:
           continue
        if sigma is not None and sigma != file_sigma:
           continue
        files_with_info.append((
            file,
            file_gene,
            file_hets,
            file_depth,
            file_sigma,
            file_theta
        ))

    file_dict_pd = pd.DataFrame(files_with_info)
    file_dict_pd.columns = ['filename','g','h','d','s','t']
    #file_dict_pd['file'] = file_dict_pd.index
    print(file_dict_pd)
    print(valid_var_np)
    print(valid_full_var_np)
    pos_pd = file_dict_pd[(file_dict_pd[valid_var_np[0]] == valid_full_var_np[0])&(file_dict_pd[valid_var_np[1]] == valid_full_var_np[1])&(file_dict_pd['t'] == theta_pos)].sort_values(['d','h','g','s'])
    print(pos_pd)
    neg_pd = file_dict_pd[(file_dict_pd[valid_var_np[0]] == valid_full_var_np[0])&(file_dict_pd[valid_var_np[1]] == valid_full_var_np[1])&(file_dict_pd['t'] == theta_neg)].sort_values(['d','h','g','s'])
    d_group = pos_pd[var_map_np[np.array(var) == None][0]].unique()
    return d_group,var,var_map_np,fixed_var_np,var_fullname_map_np,variable_var_np,pos_pd,neg_pd

# %% [markdown]
# ## semi empirical simulator

# %%
model1="iBEASTIE3"
model2="iBEASTIE3-nothetaprior"
sigma=0.7
percentError="semi_empirical/CEU/g-1000"
theta_alt=0.5
gene=1000
calculation="max_prob"
Find_cutoff_from_Null_allmodels_GIAB(model=model1, percentError=percentError,model2=model2,theta_alt=theta_alt,cutoff=null_cutoff,expected_type1error=expected_type1error,gene=gene,hets=None,depth=None,sigma=sigma,num=3,if_AA=False,calculation=calculation)

# %%
DCC_path="/data2/stan"
sigma=0.5
simulator="semi_empirical"
workdir="CEU/g-1000"
percentError="~4%"
theta_alt=0.5
cutoff=95
gene=1000
type1error=0.05
gam_model="gam4_lambdamodel.pkl"
CEU=Plot_power_curve(DCC_path,sigma,simulator,workdir,type1error,percentError,theta_alt,cutoff,lambda_model=gam_model,gene=gene,hets=None,depth=None,num=3)

# %%
CEU

# %%
DCC_path="/data2/stan"
sigma=0.5
simulator="semi_empirical"
workdir="CEU_enrichedEr/g-1000"
percentError="~13.8%"
theta_alt=0.5
cutoff=95
gene=1000
type1error=0.05
gam_model="gam4_lambdamodel.pkl"
CEU_enrich=Plot_power_curve(DCC_path,sigma,simulator,workdir,type1error,percentError,theta_alt,cutoff,lambda_model=gam_model,gene=gene,hets=None,depth=None,num=3)

# %%
CEU_enrich
